# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/MyDrive/
# %cd ProjetDM/
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/'
# /content/gdrive/My Drive/ProjetDM
# [Errno 2] No such file or directory: 'ProjetDM/'
# /content/gdrive/My Drive/ProjetDM

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/ProjetDM/.git/

# %%
# !git remote add origin https://sarrab:7ouboukaGeyton@github.com/sarrab/DMML2020_COOP
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://sarrab:7ouboukaGeyton@github.com/sarrab/DMML2020_COOP (fetch)
# origin	https://sarrab:7ouboukaGeyton@github.com/sarrab/DMML2020_COOP (push)

# %%
# !git config --global user.email sarra.berrich@gmail.com
# !git config --global user.name sarrab
# !git fetch
# Out:
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 3), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (23/23), done.
# From https://github.com/sarrab/DMML2020_COOP
#  * [new branch]      main       -> origin/main

# %%
# !git add . 
# !git commit -m "from colab"
# Out:
# [master c0e0da1] from colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (97%)

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1006 bytes | 503.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/sarrab/DMML2020_COOP
#    dd4f44c..c0e0da1  master -> master
